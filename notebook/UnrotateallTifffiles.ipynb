# %%
import sys
sys.path.append("..")
from utils_image import UnrotateTiff

# %%
#read all the imaging files in the folder
datafolder = "/media/zilong/4TB Storage HDD/2PImaging/183_27072023"
filenamelist = ["00003", "00004", "00005", "00006", "00007", "00008", "00009", "00012", "00013", "00014", "00018"]

UnrotateTiff(datafolder=datafolder, namelist = filenamelist, readVRlogs = False)
# Out:
# Unrotate Imaging Tiff files...
# Rotation center is at (255.0, 242.0)
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_27072023/27072023_00003.tif
# Randomly select 83 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_27072023/27072023_00004.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_27072023/27072023_00005.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_27072023/27072023_00006.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_27072023/27072023_00007.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_27072023/27072023_00008.tif
# ...

# %%
#read all the imaging files in the folder
datafolder = "/media/zilong/4TB Storage HDD/2PImaging/183_28072023"
filenamelist = ["00002", "00003", "00004", "00005", "00006", "00007", "00008", "00010", "00013", "00015", "00016"]

UnrotateTiff(datafolder=datafolder, namelist = filenamelist, readVRlogs = False)

# %%
#read all the imaging files in the folder
datafolder = "/media/zilong/4TB Storage HDD/2PImaging/183_31072023"
filenamelist = ["00001", "00003", "00005", "00006", "00007", "00008", "00009", "00010", "00013", "00014"]

UnrotateTiff(datafolder=datafolder, namelist = filenamelist, readVRlogs = False)

# %%
#read all the imaging files in the folder
datafolder = "/media/zilong/4TB Storage HDD/2PImaging/183_04082023"
filenamelist = ["00019", "00020", "00022", "00027", "00028", "00029", "00030", "00031", "00032", "00033", "00034", "00035", "00038"]

UnrotateTiff(datafolder=datafolder, namelist = filenamelist, readVRlogs = False)
# Out:
# Unrotate Imaging Tiff files...
# Rotation center is at (254.0, 259.0)
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_04082023/04082023_00019.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_04082023/04082023_00020.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_04082023/04082023_00022.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_04082023/04082023_00027.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_04082023/04082023_00028.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_04082023/04082023_00029.tif
# ...

# %%
#read all the imaging files in the folder
datafolder = "/media/zilong/4TB Storage HDD/2PImaging/183_06082023_superficial"
filenamelist = ["00003", "00005", "00008", "00009", "00012", "00013", "00016", "00017"]

UnrotateTiff(datafolder=datafolder, namelist = filenamelist, readVRlogs = False)
# Out:
# Unrotate Imaging Tiff files...
# Rotation center is at (264.0, 259.0)
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_superficial/06082023_00003.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_superficial/06082023_00005.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_superficial/06082023_00008.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_superficial/06082023_00009.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_superficial/06082023_00012.tif
# Randomly select 90 frames to average over...
# ...

# %%
#read all the imaging files in the folder
datafolder = "/media/zilong/4TB Storage HDD/2PImaging/183_06082023_deep"
filenamelist = ["00006", "00007", "00010", "00011", "00014", "00015", "00018", "00019", "00020"]

UnrotateTiff(datafolder=datafolder, namelist = filenamelist, readVRlogs = False)
# Out:
# Unrotate Imaging Tiff files...
# Rotation center is at (264.0, 259.0)
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_deep/06082023_00006.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_deep/06082023_00007.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_deep/06082023_00010.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_deep/06082023_00011.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_deep/06082023_00014.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/183_06082023_deep/06082023_00015.tif
# ...

# %%
#read all the imaging files in the folder
datafolder = "/media/zilong/4TB Storage HDD/2PImaging/184_06082023_deep"
filenamelist = ["00006", "00007", "00008", "00009", "00010", "00011", "00012", "00013", "00014"]

UnrotateTiff(datafolder=datafolder, namelist = filenamelist, readVRlogs = False)
# Out:
# Unrotate Imaging Tiff files...
# Rotation center is at (256.0, 242.0)
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_deep/06082023_00006.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_deep/06082023_00007.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_deep/06082023_00008.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_deep/06082023_00009.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_deep/06082023_00010.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_deep/06082023_00011.tif
# ...

# %%
#read all the imaging files in the folder
datafolder = "/media/zilong/4TB Storage HDD/2PImaging/184_06082023_superficial"
filenamelist = ["000015", "00016", "00017", "00018", "00019", "00020", "00021", "00022", "00023"]

UnrotateTiff(datafolder=datafolder, namelist = filenamelist, readVRlogs = False)
# Out:
# Unrotate Imaging Tiff files...
# Rotation center is at (256.0, 242.0)
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_superficial/06082023_00016.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_superficial/06082023_00017.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_superficial/06082023_00018.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_superficial/06082023_00019.tif
# Randomly select 90 frames to average over...
# Get the median value of tiff file:  /media/zilong/4TB Storage HDD/2PImaging/184_06082023_superficial/06082023_00020.tif
# Randomly select 90 frames to average over...
# ...
